# %%
# !pip install pandas_profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas_profiling in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from pandas_profiling) (4.2.0)
# Requirement already satisfied: dacite>=1.8 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.8.1)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (0.1.12)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (6.0)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.23.5)
# Requirement already satisfied: pandas!=1.4.0,<2,>1.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.5.3)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (4.3.1)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (4.64.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.9.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.9.1)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (0.7.5)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (3.1.2)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.28.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.12.2)
# Requirement already satisfied: scipy<1.11,>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.10.0)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.13.5)
# Requirement already satisfied: pydantic<2,>=1.8.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.10.8)
# Requirement already satisfied: typeguard<3,>=2.13.2 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (2.13.3)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (0.12.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (3.7.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (1.4.1)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (9.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (2.8.4)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (22.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas_profiling) (2.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas!=1.4.0,<2,>1.1->ydata-profiling->pandas_profiling) (2022.7)
# Requirement already satisfied: joblib>=0.14.1 in c:\programdata\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas_profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas_profiling) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (1.26.14)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (0.5.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas_profiling) (0.4.6)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (1.16.0)

# %%
# !pip install --upgrade pandas_profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas_profiling in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from pandas_profiling) (4.2.0)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (6.0)
# Requirement already satisfied: scipy<1.11,>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.10.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (3.1.2)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (0.12.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (0.1.12)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (4.64.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.10.8)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (0.7.5)
# Requirement already satisfied: dacite>=1.8 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.8.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.9.2)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (4.3.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.13.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.23.5)
# Requirement already satisfied: pandas!=1.4.0,<2,>1.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.5.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (3.7.0)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.28.1)
# Requirement already satisfied: typeguard<3,>=2.13.2 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (2.13.3)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from ydata-profiling->pandas_profiling) (1.9.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.12.2)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (9.4.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (1.4.1)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (2.8.4)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\nethrashri\appdata\roaming\python\python310\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (22.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas_profiling) (2.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas!=1.4.0,<2,>1.1->ydata-profiling->pandas_profiling) (2022.7)
# Requirement already satisfied: joblib>=0.14.1 in c:\programdata\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas_profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas_profiling) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (1.26.14)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (0.5.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas_profiling) (0.4.6)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (1.16.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "hh114.ann.features.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    lastSensorEventHours  lastSensorEventSeconds  lastSensorDayOfWeek  \
# 0                   0.0                  3074.0                  2.0
# 1                   0.0                  3075.0                  2.0
# 2                   0.0                  3075.0                  2.0
# 3                   0.0                  3080.0                  2.0
# 4                   0.0                  3081.0                  2.0
#
#    windowDuration  timeSinceLastSensorEvent  prevDominantSensor1  \
# 0          2050.0                       0.0                  0.0
# 1          1621.0                       1.0                  0.0
# 2          1021.0                       0.0                  0.0
# 3           856.0                       5.0                  0.0
# 4            43.0                       1.0                  0.0
#
#    prevDominantSensor2  lastSensorID  lastSensorLocation  lastMotionLocation  \
# 0                  0.0           1.0                 1.0                 1.0
# 1                  0.0           5.0                 5.0                 1.0
# 2                  0.0           1.0                 1.0                 1.0
# 3                  0.0           1.0                 1.0                 1.0
# 4                  0.0           1.0                 1.0                 1.0
#
#    ...  sensorElTime-Chair  sensorElTime-DiningRoom  sensorElTime-Hall  \
# 0  ...             86400.0                  86400.0            86400.0
# 1  ...             86400.0                  86400.0            86400.0
# 2  ...             86400.0                  86400.0            86400.0
# 3  ...             86400.0                  86400.0            86400.0
# 4  ...             86400.0                  86400.0            86400.0
#
#    sensorElTime-Ignore  sensorElTime-Kitchen  sensorElTime-LivingRoom  \
# 0            12.186482               86400.0                  86400.0
# 1             0.000000               86400.0                  86400.0
# 2             0.032108               86400.0                  86400.0
# 3             4.501647               86400.0                  86400.0
# 4             5.630662               86400.0                  86400.0
#
#    sensorElTime-Office  sensorElTime-OutsideDoor  sensorElTime-WorkArea  \
# 0              86400.0                   86400.0                86400.0
# 1              86400.0                   86400.0                86400.0
# 2              86400.0                   86400.0                86400.0
# 3              86400.0                   86400.0                86400.0
# 4              86400.0                   86400.0                86400.0
#
#    activity
# 0     Sleep
# 1     Sleep
# 2     Sleep
# 3     Sleep
# 4     Sleep
#
# [5 rows x 37 columns]

# %%
import pandas_profiling as p
# Out:
# C:\Users\Nethrashri\AppData\Local\Temp\ipykernel_11156\1542671872.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as p

# %%
import ydata_profiling

# %%
data = pd.DataFrame(df)
print(data)
# Out:
#         lastSensorEventHours  lastSensorEventSeconds  lastSensorDayOfWeek  \
# 0                        0.0                  3074.0                  2.0
# 1                        0.0                  3075.0                  2.0
# 2                        0.0                  3075.0                  2.0
# 3                        0.0                  3080.0                  2.0
# 4                        0.0                  3081.0                  2.0
# ...                      ...                     ...                  ...
# 192509                  11.0                 40881.0                  4.0
# 192510                  11.0                 40954.0                  4.0
# 192511                  11.0                 40981.0                  4.0
# 192512                  11.0                 40983.0                  4.0
# 192513                  11.0                 40985.0                  4.0
#
#         windowDuration  timeSinceLastSensorEvent  prevDominantSensor1  \
# 0               2050.0                       0.0                  0.0
# 1               1621.0                       1.0                  0.0
# 2               1021.0                       0.0                  0.0
# 3                856.0                       5.0                  0.0
# 4                 43.0                       1.0                  0.0
# ...                ...                       ...                  ...
# 192509          1562.0                     265.0                  6.0
# 192510          1635.0                      73.0                  6.0
# 192511          1662.0                      27.0                  6.0
# 192512          1662.0                       2.0                  6.0
# 192513          1658.0                       2.0                  6.0
#
#         prevDominantSensor2  lastSensorID  lastSensorLocation  \
# 0                       0.0           1.0                 1.0
# 1                       0.0           5.0                 5.0
# 2                       0.0           1.0                 1.0
# 3                       0.0           1.0                 1.0
# 4                       0.0           1.0                 1.0
# ...                     ...           ...                 ...
# 192509                  6.0           5.0                 5.0
# 192510                  6.0           5.0                 5.0
# 192511                  6.0           5.0                 5.0
# 192512                  6.0           5.0                 5.0
# 192513                  6.0           5.0                 5.0
#
#         lastMotionLocation  ...  sensorElTime-Chair  sensorElTime-DiningRoom  \
# 0                      1.0  ...             86400.0                  86400.0
# 1                      1.0  ...             86400.0                  86400.0
# 2                      1.0  ...             86400.0                  86400.0
# 3                      1.0  ...             86400.0                  86400.0
# 4                      1.0  ...             86400.0                  86400.0
# ...                    ...  ...                 ...                      ...
# 192509                 1.0  ...             86400.0                  86400.0
# 192510                 1.0  ...             86400.0                  86400.0
# 192511                 1.0  ...             86400.0                  86400.0
# 192512                 1.0  ...             86400.0                  86400.0
# 192513                 1.0  ...             86400.0                  86400.0
#
#         sensorElTime-Hall  sensorElTime-Ignore  sensorElTime-Kitchen  \
# 0                 86400.0            12.186482          86400.000000
# 1                 86400.0             0.000000          86400.000000
# 2                 86400.0             0.032108          86400.000000
# 3                 86400.0             4.501647          86400.000000
# 4                 86400.0             5.630662          86400.000000
# ...                   ...                  ...                   ...
# 192509            86400.0             0.000000           1567.189295
# 192510            86400.0             0.000000           1640.322392
# 192511            86400.0             0.000000           1666.861197
# 192512            86400.0             0.000000           1668.697426
# 192513            86400.0             0.000000           1670.429900
#
#         sensorElTime-LivingRoom  sensorElTime-Office  \
# 0                  86400.000000              86400.0
# 1                  86400.000000              86400.0
# 2                  86400.000000              86400.0
# 3                  86400.000000              86400.0
# 4                  86400.000000              86400.0
# ...                         ...                  ...
# 192509              1563.408893              86400.0
# 192510              1636.541990              86400.0
# 192511              1663.080795              86400.0
# 192512              1664.917024              86400.0
# 192513              1666.649498              86400.0
#
#         sensorElTime-OutsideDoor  sensorElTime-WorkArea        activity
# 0                   86400.000000                86400.0           Sleep
# 1                   86400.000000                86400.0           Sleep
# 2                   86400.000000                86400.0           Sleep
# 3                   86400.000000                86400.0           Sleep
# 4                   86400.000000                86400.0           Sleep
# ...                          ...                    ...             ...
# 192509               1718.618976                86400.0  Other_Activity
# 192510               1791.752073                86400.0  Other_Activity
# 192511               1818.290878                86400.0  Other_Activity
# 192512               1820.127107                86400.0  Other_Activity
# 192513               1821.859581                86400.0  Other_Activity
#
# [192514 rows x 37 columns]

# %%
profile = p.ProfileReport(data)
profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data.tail()
# Out:
#         lastSensorEventHours  lastSensorEventSeconds  lastSensorDayOfWeek  \
# 192509                  11.0                 40881.0                  4.0
# 192510                  11.0                 40954.0                  4.0
# 192511                  11.0                 40981.0                  4.0
# 192512                  11.0                 40983.0                  4.0
# 192513                  11.0                 40985.0                  4.0
#
#         windowDuration  timeSinceLastSensorEvent  prevDominantSensor1  \
# 192509          1562.0                     265.0                  6.0
# 192510          1635.0                      73.0                  6.0
# 192511          1662.0                      27.0                  6.0
# 192512          1662.0                       2.0                  6.0
# 192513          1658.0                       2.0                  6.0
#
#         prevDominantSensor2  lastSensorID  lastSensorLocation  \
# 192509                  6.0           5.0                 5.0
# 192510                  6.0           5.0                 5.0
# 192511                  6.0           5.0                 5.0
# 192512                  6.0           5.0                 5.0
# 192513                  6.0           5.0                 5.0
#
#         lastMotionLocation  ...  sensorElTime-Chair  sensorElTime-DiningRoom  \
# 192509                 1.0  ...             86400.0                  86400.0
# 192510                 1.0  ...             86400.0                  86400.0
# 192511                 1.0  ...             86400.0                  86400.0
# 192512                 1.0  ...             86400.0                  86400.0
# 192513                 1.0  ...             86400.0                  86400.0
#
#         sensorElTime-Hall  sensorElTime-Ignore  sensorElTime-Kitchen  \
# 192509            86400.0                  0.0           1567.189295
# 192510            86400.0                  0.0           1640.322392
# 192511            86400.0                  0.0           1666.861197
# 192512            86400.0                  0.0           1668.697426
# 192513            86400.0                  0.0           1670.429900
#
#         sensorElTime-LivingRoom  sensorElTime-Office  \
# 192509              1563.408893              86400.0
# 192510              1636.541990              86400.0
# 192511              1663.080795              86400.0
# 192512              1664.917024              86400.0
# 192513              1666.649498              86400.0
#
#         sensorElTime-OutsideDoor  sensorElTime-WorkArea        activity
# 192509               1718.618976                86400.0  Other_Activity
# 192510               1791.752073                86400.0  Other_Activity
# 192511               1818.290878                86400.0  Other_Activity
# 192512               1820.127107                86400.0  Other_Activity
# 192513               1821.859581                86400.0  Other_Activity
#
# [5 rows x 37 columns]

# %%
# View the first few rows of the dataset
print(df.head())
# Out:
#    lastSensorEventHours  lastSensorEventSeconds  lastSensorDayOfWeek  \
# 0                   0.0                  3074.0                  2.0
# 1                   0.0                  3075.0                  2.0
# 2                   0.0                  3075.0                  2.0
# 3                   0.0                  3080.0                  2.0
# 4                   0.0                  3081.0                  2.0
#
#    windowDuration  timeSinceLastSensorEvent  prevDominantSensor1  \
# 0          2050.0                       0.0                  0.0
# 1          1621.0                       1.0                  0.0
# 2          1021.0                       0.0                  0.0
# 3           856.0                       5.0                  0.0
# 4            43.0                       1.0                  0.0
#
#    prevDominantSensor2  lastSensorID  lastSensorLocation  lastMotionLocation  \
# 0                  0.0           1.0                 1.0                 1.0
# 1                  0.0           5.0                 5.0                 1.0
# 2                  0.0           1.0                 1.0                 1.0
# 3                  0.0           1.0                 1.0                 1.0
# 4                  0.0           1.0                 1.0                 1.0
#
#    ...  sensorElTime-Chair  sensorElTime-DiningRoom  sensorElTime-Hall  \
# 0  ...             86400.0                  86400.0            86400.0
# 1  ...             86400.0                  86400.0            86400.0
# 2  ...             86400.0                  86400.0            86400.0
# 3  ...             86400.0                  86400.0            86400.0
# 4  ...             86400.0                  86400.0            86400.0
#
#    sensorElTime-Ignore  sensorElTime-Kitchen  sensorElTime-LivingRoom  \
# 0            12.186482               86400.0                  86400.0
# 1             0.000000               86400.0                  86400.0
# 2             0.032108               86400.0                  86400.0
# 3             4.501647               86400.0                  86400.0
# 4             5.630662               86400.0                  86400.0
#
#    sensorElTime-Office  sensorElTime-OutsideDoor  sensorElTime-WorkArea  \
# 0              86400.0                   86400.0                86400.0
# 1              86400.0                   86400.0                86400.0
# 2              86400.0                   86400.0                86400.0
# 3              86400.0                   86400.0                86400.0
# 4              86400.0                   86400.0                86400.0
#
#    activity
# 0     Sleep
# 1     Sleep
# 2     Sleep
# 3     Sleep
# 4     Sleep
#
# [5 rows x 37 columns]

# %%
# Get the summary statistics of the dataset
print(df.describe())
# Out:
#        lastSensorEventHours  lastSensorEventSeconds  lastSensorDayOfWeek  \
# count         192514.000000           192514.000000        192514.000000
# mean              13.233380            49468.672663             2.955167
# std                5.521514            19932.394632             1.941713
# min                0.000000                0.000000             0.000000
# 25%                9.000000            35972.000000             1.000000
# 50%               13.000000            48220.000000             3.000000
# 75%               18.000000            66055.000000             5.000000
# max               23.000000            86399.000000             6.000000
#
#        windowDuration  timeSinceLastSensorEvent  prevDominantSensor1  \
# count   192514.000000             192514.000000        192514.000000
# mean       396.077122                 13.660882             5.028227
# std       1275.064733                131.732590             2.319618
# min          6.000000                  0.000000             0.000000
# 25%         35.000000                  0.000000             5.000000
# 50%         59.000000                  1.000000             6.000000
# 75%        136.000000                  2.000000             7.000000
# max      23284.000000              15281.000000             9.000000
#
#        prevDominantSensor2   lastSensorID  lastSensorLocation  \
# count        192514.000000  192514.000000       192514.000000
# mean              5.027292       5.073070            5.073070
# std               2.320435       2.134883            2.134883
# min               0.000000       0.000000            0.000000
# 25%               5.000000       5.000000            5.000000
# 50%               6.000000       6.000000            6.000000
# 75%               7.000000       6.000000            6.000000
# max               9.000000       9.000000            9.000000
#
#        lastMotionLocation  ...  sensorElTime-Bedroom  sensorElTime-Chair  \
# count       192514.000000  ...         192514.000000            192514.0
# mean             5.011391  ...           2126.082665             86400.0
# std              2.667378  ...           4366.062797                 0.0
# min             -1.000000  ...              0.000000             86400.0
# 25%              1.000000  ...             36.399598             86400.0
# 50%              6.000000  ...            386.722901             86400.0
# 75%              7.000000  ...           1701.128138             86400.0
# max              9.000000  ...          29063.787870             86400.0
#
#        sensorElTime-DiningRoom  sensorElTime-Hall  sensorElTime-Ignore  \
# count                 192514.0           192514.0        192514.000000
# mean                   86400.0            86400.0            44.507209
# std                        0.0                0.0           536.701939
# min                    86400.0            86400.0             0.000000
# 25%                    86400.0            86400.0             0.000000
# 50%                    86400.0            86400.0             0.101342
# 75%                    86400.0            86400.0             5.850866
# max                    86400.0            86400.0         15642.405349
#
#        sensorElTime-Kitchen  sensorElTime-LivingRoom  sensorElTime-Office  \
# count         192514.000000            192514.000000             192514.0
# mean            2019.081500              1128.240524              86400.0
# std             6141.729020              4938.427100                  0.0
# min                0.000000                 0.000000              86400.0
# 25%                0.000000                 0.466826              86400.0
# 50%               16.566505                49.215451              86400.0
# 75%              708.895532               324.729427              86400.0
# max            86400.000000             86400.000000              86400.0
#
#        sensorElTime-OutsideDoor  sensorElTime-WorkArea
# count             192514.000000               192514.0
# mean               10298.810678                86400.0
# std                16536.036545                    0.0
# min                    0.000000                86400.0
# 25%                  461.494453                86400.0
# 50%                 2537.951330                86400.0
# 75%                10830.836594                86400.0
# max                86400.000000                86400.0
#
# [8 rows x 36 columns]

# %%
# Check the data types of variables
print(df.dtypes)
# Out:
# lastSensorEventHours        float64
# lastSensorEventSeconds      float64
# lastSensorDayOfWeek         float64
# windowDuration              float64
# timeSinceLastSensorEvent    float64
# prevDominantSensor1         float64
# prevDominantSensor2         float64
# lastSensorID                float64
# lastSensorLocation          float64
# lastMotionLocation          float64
# complexity                  float64
# activityChange              float64
# areaTransitions             float64
# numDistinctSensors          float64
# sensorCount-Bathroom        float64
# sensorCount-Bedroom         float64
# sensorCount-Chair           float64
# sensorCount-DiningRoom      float64
# sensorCount-Hall            float64
# sensorCount-Ignore          float64
# sensorCount-Kitchen         float64
# sensorCount-LivingRoom      float64
# sensorCount-Office          float64
# sensorCount-OutsideDoor     float64
# sensorCount-WorkArea        float64
# sensorElTime-Bathroom       float64
# sensorElTime-Bedroom        float64
# sensorElTime-Chair          float64
# sensorElTime-DiningRoom     float64
# sensorElTime-Hall           float64
# sensorElTime-Ignore         float64
# sensorElTime-Kitchen        float64
# sensorElTime-LivingRoom     float64
# sensorElTime-Office         float64
# sensorElTime-OutsideDoor    float64
# sensorElTime-WorkArea       float64
# activity                     object
# dtype: object

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# lastSensorEventHours        0
# lastSensorEventSeconds      0
# lastSensorDayOfWeek         0
# windowDuration              0
# timeSinceLastSensorEvent    0
# prevDominantSensor1         0
# prevDominantSensor2         0
# lastSensorID                0
# lastSensorLocation          0
# lastMotionLocation          0
# complexity                  0
# activityChange              0
# areaTransitions             0
# numDistinctSensors          0
# sensorCount-Bathroom        0
# sensorCount-Bedroom         0
# sensorCount-Chair           0
# sensorCount-DiningRoom      0
# sensorCount-Hall            0
# sensorCount-Ignore          0
# sensorCount-Kitchen         0
# sensorCount-LivingRoom      0
# sensorCount-Office          0
# sensorCount-OutsideDoor     0
# sensorCount-WorkArea        0
# sensorElTime-Bathroom       0
# sensorElTime-Bedroom        0
# sensorElTime-Chair          0
# sensorElTime-DiningRoom     0
# sensorElTime-Hall           0
# sensorElTime-Ignore         0
# sensorElTime-Kitchen        0
# sensorElTime-LivingRoom     0
# sensorElTime-Office         0
# sensorElTime-OutsideDoor    0
# sensorElTime-WorkArea       0
# activity                    0
# dtype: int64

# %%
# Drop duplicates
df = df.drop_duplicates()
